# %% [markdown]
# # Format and Label MTS-Dialog Data

# %% [markdown]
# ## Parse Questions and Answers

# %%
import pandas as pd
import re

# Load the MTS-Dialog file
mts_df = pd.read_csv("MTS-Dialog-TrainingSet.csv")

q_df = pd.DataFrame({
    "encounter_id" : [],
    "turn_id" : [],
    "doctor_q" : [],
})

a_df = pd.DataFrame({
    "encounter_id" : [],
    "turn_id" : [],
    "patient_a" : [],
})

encounter_id = 0
turn_id = 0

for _, rec in mts_df.iterrows():

    dialogue = rec["dialogue"]
    segments = re.findall(
        r"(Doctor|Patient|Guest_family(?:_\d+)?):\s*(.*?)\s*(?=Doctor:|Patient:|Guest_family|Guest_clinician|$)",
        dialogue, flags=re.DOTALL
    )

    for speaker, utterance in segments:
        if speaker == "Doctor":
            q_df.loc[len(q_df)] = {
                "encounter_id" : rec["ID"],
                "turn_id" : turn_id,
                "doctor_q" : utterance.strip()
            }
        else:
            a_df.loc[len(a_df)] = {
                "encounter_id" : rec["ID"],
                "turn_id" : turn_id,
                "patient_a" : utterance.strip()
            }      
            turn_id += 1

q_df.to_csv("output/mts_dialog_questions.csv", index=False)
a_df.to_csv("output/mts_dialog_answers.csv", index=False)

# %% [markdown]
# ## Label Findings

# %% [markdown]
# Use the kaggle_zeroshot_qa_labeling.ipynb notebook to label the emotes on mts_dialog_questions.csv and abswer types on mts_dialog_answers.csv before this. In the \output folder, you should now have:
# * mts_dialog_questions_w_emotes.csv
# * mts_dialog_answers_with_yn.csv

# %%
import pandas as pd
import json
import re

q_df = pd.read_csv("output/mts_dialog_questions_w_emotes.csv")

with open("revised_input/symptom_pattern_map.json", "r") as f:
    kb_pattern_map = json.load(f)

def extract_concept(text: str) -> str:
    for concept, regex_list in kb_pattern_map.items():
        for pattern in regex_list:
            try:
                if re.search(pattern, text, re.IGNORECASE):
                    return concept
            except: 
                return "none"
    return "none"


q_df["finding"] = q_df["doctor_q"].apply(extract_concept)

q_df.to_csv("output/mts_dialog_questions_with_emotes_and_findings.csv", index=False)
q_df
# Out:
#       encounter_id  turn_id  \
# 0                0        0
# 1                0        1
# 2                0        2
# 3                0        3
# 4                1        4
# ...            ...      ...
# 5804          1199     5475
# 5805          1199     5476
# 5806          1200     5476
# 5807          1200     5477
# 5808          1200     5478
#
#                                                doctor_q        emote  finding
# 0     What brings you back into the clinic today, miss?      Neutral     none
# 1     It looks like Doctor Kumar followed up with yo...      Neutral     none
# 2     Have you had any fever or chills, cough, conge...      Neutral    cough
# 3     Great. Also, for our records, how old are you ...  Affirmative     none
# 4                             How're you feeling today?      Neutral     none
# ...                                                 ...          ...      ...
# 5804  I'm originally from Kentucky. And I have to do...      Neutral  smoking
# 5805                                            Got it.  Affirmative     none
# 5806  Looks like the nurse came in and asked you eve...      Neutral     none
# 5807                                      Do you smoke?      Neutral  smoking
# 5808                                       Do you work?      Neutral     none
#
# [5809 rows x 5 columns]

# %% [markdown]
# ## Combine Questions and Answer

# %%
import pandas as pd

q_df = pd.read_csv("output/mts_dialog_questions_with_emotes_and_findings.csv")
a_df = pd.read_csv("output/mts_dialog_answers_with_yn.csv")
next_encounter_id = 1

qa_df = q_df.merge(a_df, on=["turn_id", "encounter_id"])

qa_df.to_csv("output/question_answer_pairs.csv", index=False)
qa_df
# Out:
#       encounter_id  turn_id  \
# 0                0        0
# 1                0        1
# 2                0        2
# 3                0        3
# 4                1        4
# ...            ...      ...
# 5437          1199     5474
# 5438          1199     5475
# 5439          1200     5476
# 5440          1200     5477
# 5441          1200     5478
#
#                                                doctor_q        emote  finding  \
# 0     What brings you back into the clinic today, miss?      Neutral     none
# 1     It looks like Doctor Kumar followed up with yo...      Neutral     none
# 2     Have you had any fever or chills, cough, conge...      Neutral    cough
# 3     Great. Also, for our records, how old are you ...  Affirmative     none
# 4                             How're you feeling today?      Neutral     none
# ...                                                 ...          ...      ...
# 5437  Awesome. I moved here in O nine, so two years ...  Affirmative     none
# 5438  I'm originally from Kentucky. And I have to do...      Neutral  smoking
# 5439  Looks like the nurse came in and asked you eve...      Neutral     none
# 5440                                      Do you smoke?      Neutral  smoking
# 5441                                       Do you work?      Neutral     none
#
#                                               patient_a affirmative
# 0     I came in for a refill of my blood pressure me...     Unknown
# 1                                                   No.       False
# 2                                                   No.       False
# 3     I am seventy six years old and identify as a w...     Unknown
# 4     Terrible. I'm having the worst headache of my ...     Unknown
# ...                                                 ...         ...
# 5437                     No way! How funny. Where from?     Unknown
# 5438                            No to all of the above.       False
# 5439  Oh, it's a senior citizen house. They have man...     Unknown
# 5440                                                No.       False
# 5441  Ah, right now I can't because of this disabili...     Unknown
#
# [5442 rows x 7 columns]

# %% [markdown]
# ## Create Final Dataset with Previous Responses

# %%
import pandas as pd

qa_df = pd.read_csv("output/question_answer_pairs.csv")
qa_df = qa_df.set_index("turn_id")
qa_df
# Out:
#          encounter_id                                           doctor_q  \
# turn_id
# 0                   0  What brings you back into the clinic today, miss?
# 1                   0  It looks like Doctor Kumar followed up with yo...
# 2                   0  Have you had any fever or chills, cough, conge...
# 3                   0  Great. Also, for our records, how old are you ...
# 4                   1                          How're you feeling today?
# ...               ...                                                ...
# 5474             1199  Awesome. I moved here in O nine, so two years ...
# 5475             1199  I'm originally from Kentucky. And I have to do...
# 5476             1200  Looks like the nurse came in and asked you eve...
# 5477             1200                                      Do you smoke?
# 5478             1200                                       Do you work?
#
#                emote  finding  \
# turn_id
# 0            Neutral     none
# 1            Neutral     none
# 2            Neutral    cough
# 3        Affirmative     none
# 4            Neutral     none
# ...              ...      ...
# 5474     Affirmative     none
# 5475         Neutral  smoking
# 5476         Neutral     none
# 5477         Neutral  smoking
# 5478         Neutral     none
#
#                                                  patient_a affirmative
# turn_id
# 0        I came in for a refill of my blood pressure me...     Unknown
# 1                                                      No.       False
# 2                                                      No.       False
# 3        I am seventy six years old and identify as a w...     Unknown
# 4        Terrible. I'm having the worst headache of my ...     Unknown
# ...                                                    ...         ...
# 5474                        No way! How funny. Where from?     Unknown
# 5475                               No to all of the above.       False
# 5476     Oh, it's a senior citizen house. They have man...     Unknown
# 5477                                                   No.       False
# 5478     Ah, right now I can't because of this disabili...     Unknown
#
# [5442 rows x 6 columns]

# %%
new_df = qa_df

for turn, row in qa_df.iterrows():
    prev_dr_turn = "none"
    prev_pt_resp = "none"   
    prev_affirmative = "none"  
    prev_finding = "none"  
    if turn > 0 :
        try:
            prev_turn = qa_df.loc[turn - 1]        
            if prev_turn["encounter_id"] == row["encounter_id"]:
                prev_dr_turn = prev_turn["doctor_q"] 
                prev_pt_resp = prev_turn["patient_a"]
                prev_affirmative = prev_turn["affirmative"]
                prev_finding = prev_turn["finding"]
        except:
            pass


    new_df.loc[turn, "prev_doctor_q"] = prev_dr_turn
    new_df.loc[turn, "prev_patient_a"] = prev_pt_resp
    new_df.loc[turn, "prev_finding"] = prev_finding
    new_df.loc[turn, "prev_affirmative"] = prev_affirmative

df_json = new_df.to_json(orient='records', lines=True)

with open("output/question_answer_dataset.jsonl", "w") as f:
    f.write(df_json + '\n')

new_df.to_csv("output/question_answer_dataset.csv", index=False)
new_df
# Out:
#          encounter_id                                           doctor_q  \
# turn_id
# 0                   0  What brings you back into the clinic today, miss?
# 1                   0  It looks like Doctor Kumar followed up with yo...
# 2                   0  Have you had any fever or chills, cough, conge...
# 3                   0  Great. Also, for our records, how old are you ...
# 4                   1                          How're you feeling today?
# ...               ...                                                ...
# 5474             1199  Awesome. I moved here in O nine, so two years ...
# 5475             1199  I'm originally from Kentucky. And I have to do...
# 5476             1200  Looks like the nurse came in and asked you eve...
# 5477             1200                                      Do you smoke?
# 5478             1200                                       Do you work?
#
#                emote  finding  \
# turn_id
# 0            Neutral     none
# 1            Neutral     none
# 2            Neutral    cough
# 3        Affirmative     none
# 4            Neutral     none
# ...              ...      ...
# 5474     Affirmative     none
# 5475         Neutral  smoking
# 5476         Neutral     none
# 5477         Neutral  smoking
# 5478         Neutral     none
#
#                                                  patient_a affirmative  \
# turn_id
# 0        I came in for a refill of my blood pressure me...     Unknown
# 1                                                      No.       False
# 2                                                      No.       False
# 3        I am seventy six years old and identify as a w...     Unknown
# 4        Terrible. I'm having the worst headache of my ...     Unknown
# ...                                                    ...         ...
# 5474                        No way! How funny. Where from?     Unknown
# 5475                               No to all of the above.       False
# 5476     Oh, it's a senior citizen house. They have man...     Unknown
# 5477                                                   No.       False
# 5478     Ah, right now I can't because of this disabili...     Unknown
#
#                                              prev_doctor_q  \
# turn_id
# 0                                                     none
# 1        What brings you back into the clinic today, miss?
# 2        It looks like Doctor Kumar followed up with yo...
# 3        Have you had any fever or chills, cough, conge...
# 4                                                     none
# ...                                                    ...
# 5474                                             How long-
# 5475     Awesome. I moved here in O nine, so two years ...
# 5476                                                  none
# 5477     Looks like the nurse came in and asked you eve...
# 5478                                         Do you smoke?
#
#                                             prev_patient_a prev_finding  \
# turn_id
# 0                                                     none         none
# 1        I came in for a refill of my blood pressure me...         none
# 2                                                      No.         none
# 3                                                      No.        cough
# 4                                                     none         none
# ...                                                    ...          ...
# 5474                             Moved up here in O seven.         none
# 5475                        No way! How funny. Where from?         none
# 5476                                                  none         none
# 5477     Oh, it's a senior citizen house. They have man...         none
# 5478                                                   No.      smoking
#
#         prev_affirmative
# turn_id
# 0                   none
# 1                Unknown
# 2                  False
# 3                  False
# 4                   none
# ...                  ...
# 5474             Unknown
# 5475             Unknown
# 5476                none
# 5477             Unknown
# 5478               False
#
# [5442 rows x 10 columns]

# %% [markdown]
# ## Combined with Simulated Cases

# %% [markdown]
# Make sure to run generate_clinical_dialogue.py first to get output/generated_cases.csv

# %%
import pandas as pd
generated_df = pd.read_csv("output/generated_cases.csv")

new_df = pd.concat([new_df, generated_df], ignore_index=True)

# %%
df_json = new_df.to_json(orient='records', lines=True)

with open("output/question_answer_dataset.jsonl", "w") as f:
    f.write(df_json + '\n')

new_df.to_csv("output/question_answer_dataset.csv", index=False)
new_df
# Out:
#        encounter_id                                           doctor_q  \
# 0                 0  What brings you back into the clinic today, miss?
# 1                 0  It looks like Doctor Kumar followed up with yo...
# 2                 0  Have you had any fever or chills, cough, conge...
# 3                 0  Great. Also, for our records, how old are you ...
# 4                 1                          How're you feeling today?
# ...             ...                                                ...
# 15437           999  Have you been experiencing any nasal congestio...
# 15438           999               Have you been experiencing insomnia?
# 15439           999                            Do you have cold hands?
# 15440           999             Are you being treated for blood clots?
# 15441           999      Are you experiencing any pain in your throat?
#
#              emote           finding  \
# 0          Neutral              none
# 1          Neutral              none
# 2          Neutral             cough
# 3      Affirmative              none
# 4          Neutral              none
# ...            ...               ...
# 15437      Neutral  nasal congestion
# 15438      Neutral          insomnia
# 15439      Neutral        cold hands
# 15440      Neutral       blood clots
# 15441      Neutral       throat pain
#
#                                                patient_a affirmative  \
# 0      I came in for a refill of my blood pressure me...     Unknown
# 1                                                    No.       False
# 2                                                    No.       False
# 3      I am seventy six years old and identify as a w...     Unknown
# 4      Terrible. I'm having the worst headache of my ...     Unknown
# ...                                                  ...         ...
# 15437                                                No.       False
# 15438                                                No.       False
# 15439                                                No.       False
# 15440                                                No.       False
# 15441                                                No.       False
#
#                                            prev_doctor_q  \
# 0                                                   none
# 1      What brings you back into the clinic today, miss?
# 2      It looks like Doctor Kumar followed up with yo...
# 3      Have you had any fever or chills, cough, conge...
# 4                                                   none
# ...                                                  ...
# 15437                     When did your foot pain start?
# 15438  Have you been experiencing any nasal congestio...
# 15439               Have you been experiencing insomnia?
# 15440                            Do you have cold hands?
# 15441             Are you being treated for blood clots?
#
#                                           prev_patient_a      prev_finding  \
# 0                                                   none              none
# 1      I came in for a refill of my blood pressure me...              none
# 2                                                    No.              none
# 3                                                    No.             cough
# 4                                                   none              none
# ...                                                  ...               ...
# 15437                                                No.         foot pain
# 15438                                                No.  nasal congestion
# 15439                                                No.          insomnia
# 15440                                                No.        cold hands
# 15441                                                No.       blood clots
#
#       prev_affirmative
# 0                 none
# 1              Unknown
# 2                False
# 3                False
# 4                 none
# ...                ...
# 15437            False
# 15438            False
# 15439            False
# 15440            False
# 15441            False
#
# [15442 rows x 10 columns]

# %% [markdown]
# ## Alternative heuristic based methods for labeling emotes and affirmative answers

# %%
import pandas as pd
import re

# %%
# rule-based emotion annotation 
def classify_emotion(text):
    text = text.lower()
    if any(x in text for x in ["sorry", "apologize", "apologies", "i regret"]):
        return "apology"
    elif any(x in text for x in ["that must be hard", "i understand", "that's unfortunate", "i'm sorry to hear", "sounds difficult", "that’s worrisome"]):
        return "empathy"
    elif any(x in text for x in ["thanks", "okay", "got it", "understood", "sure", "great", "noted", "i see", "good"]):
        return "affirmative"
    return "none"

# find prefix statements before questions
def extract_emote_phrase(text):
    # Split on question punctuation or transition
    parts = re.split(r'(?<=[.!?])\s+', text.strip())
    if len(parts) > 1:
        # Return first sentence if it looks like a preface
        if len(parts[0].split()) <= 12:
            return parts[0]
    return None

# rule based yes/no annotation
def yes_no_responses(text) :
    text = text.lower()
    if re.search("\b{x}\b", text, re.IGNORECASE) for x in ["yes", "yeah"]:
        return "yes"
    elif any(re.search("\b{x}\b", text, re.IGNORECASE) for x in ["no", "nope"]):
        return "no"
    return "none"
