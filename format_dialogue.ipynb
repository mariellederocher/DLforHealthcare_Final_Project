# %%
import pandas as pd
import re


# 2) Load the MTS-Dialog file
mts_df = pd.read_csv("MTS-Dialog-TrainingSet.csv")

q_df = pd.DataFrame({
    "encounter_id" : [],
    "turn_id" : [],
    "doctor_q" : [],
})

a_df = pd.DataFrame({
    "encounter_id" : [],
    "turn_id" : [],
    "patient_a" : [],
})

encounter_id = 0
turn_id = 0

for _, rec in mts_df.iterrows():

    dialogue = rec["dialogue"]
    segments = re.findall(
        r"(Doctor|Patient|Guest_family(?:_\d+)?):\s*(.*?)\s*(?=Doctor:|Patient:|Guest_family|Guest_clinician|$)",
        dialogue, flags=re.DOTALL
    )

    for speaker, utterance in segments:
        if speaker == "Doctor":
            q_df.loc[len(q_df)] = {
                "encounter_id" : rec["ID"],
                "turn_id" : turn_id,
                "doctor_q" : utterance.strip()
            }
        else:
            a_df.loc[len(a_df)] = {
                "encounter_id" : rec["ID"],
                "turn_id" : turn_id,
                "patient_a" : utterance.strip()
            }      
            turn_id += 1

q_df.to_csv("output/mts_dialog_questions.csv", index=False)
a_df.to_csv("output/mts_dialog_answers.csv", index=False)

q_df
a_df
# Out:
#       encounter_id  turn_id                                          patient_a
# 0                0        0  I came in for a refill of my blood pressure me...
# 1                0        1                                                No.
# 2                0        2                                                No.
# 3                0        3  I am seventy six years old and identify as a w...
# 4                1        4  Terrible. I'm having the worst headache of my ...
# ...            ...      ...                                                ...
# 5474          1199     5474                     No way! How funny. Where from?
# 5475          1199     5475                            No to all of the above.
# 5476          1200     5476  Oh, it's a senior citizen house. They have man...
# 5477          1200     5477                                                No.
# 5478          1200     5478  Ah, right now I can't because of this disabili...
#
# [5479 rows x 3 columns]

# %%
import json
import re

q_df = pd.read_csv("output/mts_dialog_questions_w_emotes.csv")

with open("revised_input/symptom_pattern_map.json", "r") as f:
    kb_pattern_map = json.load(f)

def extract_concept(text: str) -> str:
    for concept, regex_list in kb_pattern_map.items():
        for pattern in regex_list:
            try:
                if re.search(pattern, text, re.IGNORECASE):
                    return concept
            except: 
                return "none"
    return "none"

# 4) Apply to each question
q_df["finding"] = q_df["doctor_q"].apply(extract_concept)

q_df.to_csv("output/doctor_q_with_emotes_and_findings.csv", index=False)

# %%
q_df
# Out:
#       encounter_id  turn_id  \
# 0                0        0
# 1                0        1
# 2                0        2
# 3                0        3
# 4                1        4
# ...            ...      ...
# 5804          1199     5475
# 5805          1199     5476
# 5806          1200     5476
# 5807          1200     5477
# 5808          1200     5478
#
#                                                doctor_q        emote finding
# 0     What brings you back into the clinic today, miss?      Neutral    none
# 1     It looks like Doctor Kumar followed up with yo...      Neutral    none
# 2     Have you had any fever or chills, cough, conge...      Neutral   cough
# 3     Great. Also, for our records, how old are you ...  Affirmative    none
# 4                             How're you feeling today?      Neutral    none
# ...                                                 ...          ...     ...
# 5804  I'm originally from Kentucky. And I have to do...      Neutral    none
# 5805                                            Got it.  Affirmative    none
# 5806  Looks like the nurse came in and asked you eve...      Neutral    none
# 5807                                      Do you smoke?      Neutral    none
# 5808                                       Do you work?      Neutral    none
#
# [5809 rows x 5 columns]

# %%
import pandas as pd

q_df = pd.read_csv("output/doctor_q_with_emotes_and_findings.csv")
a_df = pd.read_csv("output/mts_dialog_answers.csv")
next_encounter_id = 1

qa_df = q_df.merge(a_df, on=["turn_id", "encounter_id"])


qa_df.to_csv("output/question_answer_pairs.csv", index=False)
qa_df
# Out:
#       encounter_id  turn_id  \
# 0                0        0
# 1                0        1
# 2                0        2
# 3                0        3
# 4                1        4
# ...            ...      ...
# 5437          1199     5474
# 5438          1199     5475
# 5439          1200     5476
# 5440          1200     5477
# 5441          1200     5478
#
#                                                doctor_q        emote  finding  \
# 0     What brings you back into the clinic today, miss?      Neutral     none
# 1     It looks like Doctor Kumar followed up with yo...      Neutral     none
# 2     Have you had any fever or chills, cough, conge...      Neutral    cough
# 3     Great. Also, for our records, how old are you ...  Affirmative     none
# 4                             How're you feeling today?      Neutral     none
# ...                                                 ...          ...      ...
# 5437  Awesome. I moved here in O nine, so two years ...  Affirmative     none
# 5438  I'm originally from Kentucky. And I have to do...      Neutral  smoking
# 5439  Looks like the nurse came in and asked you eve...      Neutral     none
# 5440                                      Do you smoke?      Neutral  smoking
# 5441                                       Do you work?      Neutral     none
#
#                                               patient_a
# 0     I came in for a refill of my blood pressure me...
# 1                                                   No.
# 2                                                   No.
# 3     I am seventy six years old and identify as a w...
# 4     Terrible. I'm having the worst headache of my ...
# ...                                                 ...
# 5437                     No way! How funny. Where from?
# 5438                            No to all of the above.
# 5439  Oh, it's a senior citizen house. They have man...
# 5440                                                No.
# 5441  Ah, right now I can't because of this disabili...
#
# [5442 rows x 6 columns]

# %%
import pandas as pd
qa_df = pd.read_csv("output/question_answer_pairs.csv")


qa_df = qa_df.set_index("turn_id")
qa_df
# Out:
#          encounter_id                                           doctor_q  \
# turn_id
# 0                   0  What brings you back into the clinic today, miss?
# 1                   0  It looks like Doctor Kumar followed up with yo...
# 2                   0  Have you had any fever or chills, cough, conge...
# 3                   0  Great. Also, for our records, how old are you ...
# 4                   1                          How're you feeling today?
# ...               ...                                                ...
# 5474             1199  Awesome. I moved here in O nine, so two years ...
# 5475             1199  I'm originally from Kentucky. And I have to do...
# 5476             1200  Looks like the nurse came in and asked you eve...
# 5477             1200                                      Do you smoke?
# 5478             1200                                       Do you work?
#
#                emote  finding  \
# turn_id
# 0            Neutral     none
# 1            Neutral     none
# 2            Neutral    cough
# 3        Affirmative     none
# 4            Neutral     none
# ...              ...      ...
# 5474     Affirmative     none
# 5475         Neutral  smoking
# 5476         Neutral     none
# 5477         Neutral  smoking
# 5478         Neutral     none
#
#                                                  patient_a
# turn_id
# 0        I came in for a refill of my blood pressure me...
# 1                                                      No.
# 2                                                      No.
# 3        I am seventy six years old and identify as a w...
# 4        Terrible. I'm having the worst headache of my ...
# ...                                                    ...
# 5474                        No way! How funny. Where from?
# 5475                               No to all of the above.
# 5476     Oh, it's a senior citizen house. They have man...
# 5477                                                   No.
# 5478     Ah, right now I can't because of this disabili...
#
# [5442 rows x 5 columns]

# %%
# qa_df = qa_df.set_index("turn_id")
# qa_df = qa_df.head(10)
new_df = qa_df

for turn, row in qa_df.iterrows():
    prev_dr_turn = "none"
    prev_pt_resp = "none"   
    if turn > 0 :
        try:
            prev_turn = qa_df.loc[turn - 1]        
            if prev_turn["encounter_id"] == row["encounter_id"]:
                prev_dr_turn = prev_turn["doctor_q"] 
                prev_pt_resp = prev_turn["patient_a"]
        except:
            pass

    
    # print(prev_dr_turn, prev_pt_resp)


    new_df.loc[turn, "prev_doctor_q"] = prev_dr_turn
    new_df.loc[turn, "prev_patient_a"] = prev_pt_resp

df_json = new_df.to_json(orient='records', lines=True)

with open("output/question_answer_dataset.jsonl", "w") as f:
    f.write(df_json + '\n')

new_df.to_csv("output/question_answer_dataset.csv", index=False)

new_df
# Out:
#          encounter_id                                           doctor_q  \
# turn_id
# 0                   0  What brings you back into the clinic today, miss?
# 1                   0  It looks like Doctor Kumar followed up with yo...
# 2                   0  Have you had any fever or chills, cough, conge...
# 3                   0  Great. Also, for our records, how old are you ...
# 4                   1                          How're you feeling today?
# ...               ...                                                ...
# 5474             1199  Awesome. I moved here in O nine, so two years ...
# 5475             1199  I'm originally from Kentucky. And I have to do...
# 5476             1200  Looks like the nurse came in and asked you eve...
# 5477             1200                                      Do you smoke?
# 5478             1200                                       Do you work?
#
#                emote  finding  \
# turn_id
# 0            Neutral     none
# 1            Neutral     none
# 2            Neutral    cough
# 3        Affirmative     none
# 4            Neutral     none
# ...              ...      ...
# 5474     Affirmative     none
# 5475         Neutral  smoking
# 5476         Neutral     none
# 5477         Neutral  smoking
# 5478         Neutral     none
#
#                                                  patient_a  \
# turn_id
# 0        I came in for a refill of my blood pressure me...
# 1                                                      No.
# 2                                                      No.
# 3        I am seventy six years old and identify as a w...
# 4        Terrible. I'm having the worst headache of my ...
# ...                                                    ...
# 5474                        No way! How funny. Where from?
# 5475                               No to all of the above.
# 5476     Oh, it's a senior citizen house. They have man...
# 5477                                                   No.
# 5478     Ah, right now I can't because of this disabili...
#
#                                              prev_doctor_q  \
# turn_id
# 0                                                     none
# 1        What brings you back into the clinic today, miss?
# 2        It looks like Doctor Kumar followed up with yo...
# 3        Have you had any fever or chills, cough, conge...
# 4                                                     none
# ...                                                    ...
# 5474                                             How long-
# 5475     Awesome. I moved here in O nine, so two years ...
# 5476                                                  none
# 5477     Looks like the nurse came in and asked you eve...
# 5478                                         Do you smoke?
#
#                                             prev_patient_a
# turn_id
# 0                                                     none
# 1        I came in for a refill of my blood pressure me...
# 2                                                      No.
# 3                                                      No.
# 4                                                     none
# ...                                                    ...
# 5474                             Moved up here in O seven.
# 5475                        No way! How funny. Where from?
# 5476                                                  none
# 5477     Oh, it's a senior citizen house. They have man...
# 5478                                                   No.
#
# [5442 rows x 7 columns]

# %% [markdown]
# # Format Dialogue from QA Record

# %%
import pandas as pd
import re

# %%
# Rule-based emotion annotation (simplified version from MEDCOD)
def classify_emotion(text):
    text = text.lower()
    if any(x in text for x in ["sorry", "apologize", "apologies", "i regret"]):
        return "apology"
    elif any(x in text for x in ["that must be hard", "i understand", "that's unfortunate", "i'm sorry to hear", "sounds difficult", "that’s worrisome"]):
        return "empathy"
    elif any(x in text for x in ["thanks", "okay", "got it", "understood", "sure", "great", "noted", "i see", "good"]):
        return "affirmative"
    return "none"

# Heuristic: find prefix statements before questions
def extract_emote_phrase(text):
    # Split on question punctuation or transition
    parts = re.split(r'(?<=[.!?])\s+', text.strip())
    if len(parts) > 1:
        # Return first sentence if it looks like a preface
        if len(parts[0].split()) <= 12:
            return parts[0]
    return None

def yes_no_responses(text) :
    text = text.lower()
    if re.search("\b{x}\b", text, re.IGNORECASE) for x in ["yes", "yeah"]:
        return "yes"
    elif any(re.search("\b{x}\b", text, re.IGNORECASE) for x in ["no", "nope"]):
        return "no"
    return "none"

# %%
mts_df = pd.read_csv("MTS-Dialog-TrainingSet.csv")
next_encounter_id = 1

qa_df = pd.DataFrame({
    "encounter_id" : [],
    "doctor_q" : [],
    "patient_a" : [],
    "answer_type" : []
})

for _, row in mts_df.iterrows():
    encounter_id = next_encounter_id
    next_encounter_id += 1
    if "dialogue" not in row or not isinstance(row['dialogue'], str):
        continue
    dialogue = row['dialogue']
    turns = re.findall(r"(Doctor|Patient): ([^:]+?)(?=(?:Doctor|Patient):|$)", dialogue)

    if len(turns) < 2:
        continue

    for i in range(2, len(turns) - 1, 2):
        qa_df.loc[len(qa_df)] = {
            "encounter_id" : encounter_id,
            "doctor_q" : turns[i][1],
            "patient_a" : turns[i+1][1],
            "answer_type" : yes_no_responses(turns[i+1][1])
        }

# qa_df = qa_df[qa_df["answer_type"] != "none"]

qa_df.to_csv("output/question_answer_pairs.csv", index=False)

qa_df
# Out:
#       encounter_id                                           doctor_q  \
# 0                1  It looks like Doctor Kumar followed up with yo...
# 1                1  Have you had any fever or chills, cough, conge...
# 2                1  Great. Also, for our records, how old are you ...
# 3                2  I'm so sorry. Well you are only twenty five, s...
# 4                2                                        Today? \r\n
# ...            ...                                                ...
# 3723          1200                                     How long- \r\n
# 3724          1200  Awesome. I moved here in O nine, so two years ...
# 3725          1200  I'm originally from Kentucky. And I have to do...
# 3726          1201                                 Do you smoke? \r\n
# 3727          1201                                  Do you work? \r\n
#
#                                               patient_a answer_type
# 0                                              No. \r\n        none
# 1                                             No.  \r\n        none
# 2     I am seventy six years old and identify as a w...        none
# 3                    Around eleven in the morning. \r\n        none
# 4              Um no yesterday. July thirty first. \r\n        none
# ...                                                 ...         ...
# 3723                     Moved up here in O seven. \r\n        none
# 3724                 No way! How funny. Where from?\r\n        none
# 3725                       No to all of the above. \r\n        none
# 3726                                           No. \r\n        none
# 3727  Ah, right now I can't because of this disabili...        none
#
# [3728 rows x 4 columns]

# %%
import pandas as pd
qa_df = pd.read_csv("output/question_answer_pairs.csv")

qa_df
# Out:
#       encounter_id                                           doctor_q  \
# 0                1  It looks like Doctor Kumar followed up with yo...
# 1                1  Have you had any fever or chills, cough, conge...
# 2                1  Great. Also, for our records, how old are you ...
# 3                2  I'm so sorry. Well you are only twenty five, s...
# 4                2                                        Today? \r\n
# ...            ...                                                ...
# 3723          1200                                     How long- \r\n
# 3724          1200  Awesome. I moved here in O nine, so two years ...
# 3725          1200  I'm originally from Kentucky. And I have to do...
# 3726          1201                                 Do you smoke? \r\n
# 3727          1201                                  Do you work? \r\n
#
#                                               patient_a answer_type
# 0                                              No. \r\n          no
# 1                                             No.  \r\n          no
# 2     I am seventy six years old and identify as a w...        none
# 3                    Around eleven in the morning. \r\n        none
# 4              Um no yesterday. July thirty first. \r\n          no
# ...                                                 ...         ...
# 3723                     Moved up here in O seven. \r\n        none
# 3724                 No way! How funny. Where from?\r\n          no
# 3725                       No to all of the above. \r\n          no
# 3726                                           No. \r\n          no
# 3727  Ah, right now I can't because of this disabili...        none
#
# [3728 rows x 4 columns]

# %%
import json
import re

kb_qa_df = qa_df



with open("revised_input/symptom_pattern_map.json", "r") as f:
    kb_pattern_map = json.load(f)



def extract_concept(text: str) -> str:
    for concept, regex_list in kb_pattern_map.items():
        for pattern in regex_list:
            if re.search("\b{pattern}\b", text, re.IGNORECASE):
                return concept
    return "none"

# 4) Apply to each question
kb_qa_df["kb_concept"] = kb_qa_df["doctor_q"].apply(extract_concept)

kb_qa_df.to_csv("output/qa_with_kb_labels.csv", index=False)

# %%
kb_qa_df = pd.read_csv("output/qa_with_kb_labels.csv")

kb_qa_df[kb_qa_df["kb_concept"] != "none"].to_csv("output/qa_labled_subset.csv", index=False)

# %%
df = pd.DataFrame({
    "encounter_id" : [],
    "prev_dr_turn" : [], 
    "prev_pt_resp" : [], 
    "answer_type" : [],
    "curr_dr_turn" : [],
    "kb_concept" : [],
    "emote" : [],
    "emote_phrase" : []
})

prev_row = pd.Series()

for index, row in kb_qa_df.iterrows():
    if prev_row.any() and prev_row["encounter_id"] == row["encounter_id"]:
        prev_dr_turn = prev_row["doctor_q"] 
        prev_pt_resp = prev_row["patient_a"]
    else :
        prev_dr_turn = "none"
        prev_pt_resp = "none"       

    emote = classify_emotion(row["doctor_q"])
    phrase = extract_emote_phrase(row["doctor_q"])

    df.loc[len(df)] = {
        "encounter_id" : encounter_id,
        "prev_dr_turn" : prev_dr_turn, 
        "prev_pt_resp" : prev_pt_resp, 
        "answer_type" : row["answer_type"],
        "curr_dr_turn" : row["doctor_q"],
        "kb_concept" : row["kb_concept"],
        "emote" : emote,
        "emote_phrase" : phrase
    }   

    prev_row = row
        

df = df[df["kb_concept"] != "none"]

df.to_csv("output/formatted_dialogue.csv", index=False)

df
# Out:
#       encounter_id                                       prev_dr_turn  \
# 1             1201  It looks like Doctor Kumar followed up with yo...
# 6             1201  July thirty first O eight. Got it. Did it come...
# 69            1201  Did you ever have a feeling where you felt lik...
# 73            1201                                               none
# 80            1201   How many episodes of vomiting have you had? \r\n
# ...            ...                                                ...
# 3672          1201  Have you had a cough, or coughed up any blood....
# 3675          1201                                               none
# 3678          1201                          Okay, any chest pain?\r\n
# 3686          1201  Let's see what we got here. Your reading says ...
# 3691          1201          Oh, tell me what's going on with you?\r\n
#
#                                            prev_pt_resp answer_type  \
# 1                                              No. \r\n          no
# 6                                            Yeah. \r\n        none
# 69                                             No. \r\n          no
# 73                                                 none         yes
# 80                                  At least four. \r\n        none
# ...                                                 ...         ...
# 3672                    That's a negative, doctor. \r\n          no
# 3675                                               none          no
# 3678                                        Um, no.\r\n          no
# 3686  Yes, I'm exercising as a rule three times ever...          no
# 3691         I have this leg pain on my left side. \r\n         yes
#
#                                            curr_dr_turn           kb_concept  \
# 1     Have you had any fever or chills, cough, conge...         Fever/Chills
# 6     Are you having any symptoms with it, such as b...            dizziness
# 69    How about any fatigue or pain? Any frequency i...              fatigue
# 73    And you got right side shoulder pain? Is this ...        shoulder pain
# 80    Any abdominal pain, fever, chill, or other sym...         Fever/Chills
# ...                                                 ...                  ...
# 3672  What about shortness of breath while at rest o...  shortness of breath
# 3675  No nausea and vomiting or black stool? Did you...  nausea and vomiting
# 3678  Any shortness of breath, cough or cold like sy...                cough
# 3686  Do you feel any tingling or numbness or any ki...             numbness
# 3691                             Hm, left leg pain?\r\n             leg pain
#
#             emote                            emote_phrase
# 1     affirmative                                    None
# 6            none                                    None
# 69           none          How about any fatigue or pain?
# 73           none   And you got right side shoulder pain?
# 80           none                                    None
# ...           ...                                     ...
# 3672         none                                    None
# 3675         none  No nausea and vomiting or black stool?
# 3678         none                                    None
# 3686         none                                    None
# 3691         none                                    None
#
# [201 rows x 8 columns]

# %%
# Replace 'none' and NaN with empty strings to avoid inserting "none" in dialogue
df_cleaned = df.replace('none', '').fillna('')

# Group by encounter_id to build conversations
grouped = df_cleaned.groupby('encounter_id')

# EOS token for DialoGPT
eos_token = "<|endoftext|>"

# Build formatted dialogues
dialogues = []

for encounter_id, group in grouped:
    turns = []
    for _, row in group.iterrows():
        # Interleave turns
        if row['prev_dr_turn'].strip():
            turns.append(f"Doctor: {row['prev_dr_turn'].strip()}")
        if row['prev_pt_resp'].strip():
            turns.append(f"Patient: {row['prev_pt_resp'].strip()}")
        if row['curr_dr_turn'].strip():
            emote = f"[{row['emote']}]" if row['emote'] else ""
            turns.append(f"Doctor{emote}: {row['curr_dr_turn'].strip()}")

    # Join the turns with EOS separator
    full_dialogue = eos_token.join(turns) + eos_token
    dialogues.append({
        "encounter_id": encounter_id,
        "dialogue": full_dialogue
    })

# Convert to DataFrame
dialogue_df = pd.DataFrame(dialogues)


# Save the processed dialogue to a JSONL file suitable for HuggingFace fine-tuning
output_path = "output/dialogpt_finetune_dataset.jsonl"
dialogue_df.to_json(output_path, orient="records", lines=True)

# Preview the output
dialogue_df.head()
# Out:
#    encounter_id                                           dialogue
# 0          1201  Doctor: It looks like Doctor Kumar followed up...

# %% [markdown]
# # Generate Cases

# %%
from MedicalKnowledgeBase import MedicalKnowledgeBase

kb = MedicalKnowledgeBase('output/mimic_4_kb_w_freq.json')

# kb = MedicalKnowledgeBase()
# kb.load_kb()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[113], line 3
#       1 from MedicalKnowledgeBase import MedicalKnowledgeBase
# ----> 3 kb = MedicalKnowledgeBase('output/mimic_4_kb_w_freq.json')
#       5 # kb = MedicalKnowledgeBase()
#       6 # kb.load_kb()
#
# File c:\Users\Ellie\OneDrive\School_Stuff\1-CurrentClasses\CS_598_Deep_Learning_for_Health_Care\DLforHealthcare_Final_Project\MedicalKnowledgeBase.py:22, in MedicalKnowledgeBase.__init__(self, kb_json_file)
#      20 for diagnosis in data:
#      21     for finding in data[diagnosis]:
# ---> 22         self.add_entry(diagnosis, finding, 1, data[diagnosis][finding])
#
# File c:\Users\Ellie\OneDrive\School_Stuff\1-CurrentClasses\CS_598_Deep_Learning_for_Health_Care\DLforHealthcare_Final_Project\MedicalKnowledgeBase.py:29, in MedicalKnowledgeBase.add_entry(self, diagnosis, finding, evoking_strength, frequency)
#      27 def add_entry(self, diagnosis, finding, evoking_strength, frequency):
#      28     self.df.loc[len(self.df)] = [diagnosis, finding, evoking_strength, frequency]
# ---> 29     self.diagnosis_list = self.df['diagnosis'].unique()
#
# File c:\Users\Ellie\OneDrive\School_Stuff\1-CurrentClasses\CS_598_Deep_Learning_for_Health_Care\DLforHealthcare_Final_Project\.venv\lib\site-packages\pandas\core\series.py:2407, in Series.unique(self)
#    2344 def unique(self) -> ArrayLike:  # pylint: disable=useless-parent-delegation
#    2345     """
#    2346     Return unique values of Series object.
#    2347
#    (...)
#    2405     Categories (3, object): ['a' < 'b' < 'c']
#    2406     """
# -> 2407     return super().unique()
#
# File c:\Users\Ellie\OneDrive\School_Stuff\1-CurrentClasses\CS_598_Deep_Learning_for_Health_Care\DLforHealthcare_Final_Project\.venv\lib\site-packages\pandas\core\base.py:1025, in IndexOpsMixin.unique(self)
#    1023     result = values.unique()
#    1024 else:
# -> 1025     result = algorithms.unique1d(values)
#    1026 return result
#
# File c:\Users\Ellie\OneDrive\School_Stuff\1-CurrentClasses\CS_598_Deep_Learning_for_Health_Care\DLforHealthcare_Final_Project\.venv\lib\site-packages\pandas\core\algorithms.py:401, in unique(values)
#     307 def unique(values):
#     308     """
#     309     Return unique values based on a hash table.
#     310
#    (...)
#     399     array([('a', 'b'), ('b', 'a'), ('a', 'c')], dtype=object)
#     400     """
# --> 401     return unique_with_mask(values)
#
# File c:\Users\Ellie\OneDrive\School_Stuff\1-CurrentClasses\CS_598_Deep_Learning_for_Health_Care\DLforHealthcare_Final_Project\.venv\lib\site-packages\pandas\core\algorithms.py:440, in unique_with_mask(values, mask)
#     438 table = hashtable(len(values))
#     439 if mask is None:
# --> 440     uniques = table.unique(values)
#     441     uniques = _reconstruct_data(uniques, original.dtype, original)
#     442     return uniques
#
# KeyboardInterrupt:

# %%
import json 

encounter_id = 0
cases_to_generate = 10
cases = []


for i in range(cases_to_generate):
    cases.append({
        "encounter_id" : encounter_id,
        "findings" : kb.get_random_findings(10)
    })
    encounter_id += 1

with open("output/simulated_cases.json", "w") as f:
    json.dump(cases, f, indent=2)

# %%
import json 
with open("output/simulated_cases.json") as f:
    cases = json.load(f)

# print(cases)

with open("revised_input/symptom_questions.json") as f:
    questions = json.load(f)

print(questions)
# Out:
# {'abdominal pain': ['Have you been experiencing any abdominal pain recently?', 'When did your abdominal pain start?', 'Are you experiencing abdominal pain?', 'Has your abdominal pain gotten better or worse recently?', 'Do you have any abdominal pain?'], 'anal pain': ['Do you have any anal pain?', 'Has your anal pain gotten better or worse recently?', 'When did your anal pain start?', 'Are you experiencing anal pain?', 'Have you been experiencing any anal pain recently?'], 'ankle pain': ['Have you been experiencing any ankle pain recently?', 'Do you have any ankle pain?', 'Are you experiencing ankle pain?', 'Has your ankle pain gotten better or worse recently?', 'When did your ankle pain start?'], 'arm pain': ['Have you been experiencing any arm pain recently?', 'When did your arm pain start?', 'Are you experiencing arm pain?', 'Do you have any arm pain?', 'Has your arm pain gotten better or worse recently?'], 'back pain': ['Are you experiencing back pain?', 'Do you have any back pain?', 'Have you been experiencing any back pain recently?', 'When did your back pain start?', 'Has your back pain gotten better or worse recently?'], 'bent penis': ['Do you have any bent penis?', 'Are you experiencing bent penis?', 'Have you been experiencing any bent penis recently?', 'Has your bent penis gotten better or worse recently?', 'When did your bent penis start?'], 'bleeding during pregnancy': ['Have you been experiencing any bleeding during pregnancy recently?', 'When did your bleeding during pregnancy start?', 'Do you have any bleeding during pregnancy?', 'Has your bleeding during pregnancy gotten better or worse recently?', 'Are you experiencing bleeding during pregnancy?'], 'blood clots': ['Have you been experiencing any blood clots recently?', 'When did your blood clots start?', 'Do you have any blood clots?', 'Are you experiencing blood clots?', 'Has your blood clots gotten better or worse recently?'], 'breast lumps': ['Have you been experiencing any breast lumps recently?', 'Are you experiencing breast lumps?', 'Has your breast lumps gotten better or worse recently?', 'Do you have any breast lumps?', 'When did your breast lumps start?'], 'breast rash': ['Has your breast rash gotten better or worse recently?', 'Have you been experiencing any breast rash recently?', 'Do you have any breast rash?', 'Are you experiencing breast rash?', 'When did your breast rash start?'], 'burning feet': ['Have you been experiencing any burning feet recently?', 'Has your burning feet gotten better or worse recently?', 'Do you have any burning feet?', 'Are you experiencing burning feet?', 'When did your burning feet start?'], 'cold hands': ['Do you have any cold hands?', 'Have you been experiencing any cold hands recently?', 'When did your cold hands start?', 'Has your cold hands gotten better or worse recently?', 'Are you experiencing cold hands?'], 'cough': ['Have you been experiencing any cough recently?', 'Has your cough gotten better or worse recently?', 'When did your cough start?', 'Do you have any cough?', 'Are you experiencing cough?'], 'coughing up blood': ['Has your coughing up blood gotten better or worse recently?', 'Are you experiencing coughing up blood?', 'When did your coughing up blood start?', 'Have you been experiencing any coughing up blood recently?', 'Do you have any coughing up blood?'], 'dark circles under eyes': ['Do you have any dark circles under eyes?', 'When did your dark circles under eyes start?', 'Have you been experiencing any dark circles under eyes recently?', 'Are you experiencing dark circles under eyes?', 'Has your dark circles under eyes gotten better or worse recently?'], 'diarrhea': ['Do you have any diarrhea?', 'When did your diarrhea start?', 'Has your diarrhea gotten better or worse recently?', 'Have you been experiencing any diarrhea recently?', 'Are you experiencing diarrhea?'], 'dizziness': ['Are you experiencing dizziness?', 'Do you have any dizziness?', 'Has your dizziness gotten better or worse recently? ...

# %%
import random

with open("revised_input/symptom_questions.json") as f:
    questions = json.load(f)

print(questions)

def simulate_conversation(kb, case_findings, max_turns=10):
    conversation = []
    current_findings = []
    neg_findings = []
    next_finding = kb.get_random_finding()

    for _ in range(max_turns):  
        # Ask the question
        question = generate_question(next_finding)
        
        # Simulate patient response
        answer = "Yes" if next_finding in case_findings else "No"

        # Save conversation turn
        conversation.append({
            "doctor_q": question,
            "patient_a": answer,
            "finding_queried": next_finding,
            "response_positive": (answer == "Yes")
        })

        # print({
        #     "doctor_q": question,
        #     "patient_a": answer,
        #     "finding_queried": next_finding,
        #     "response_positive": (answer == "Yes")
        # })

        # Update what findings have been asked
        if answer == "Yes":
            current_findings.append(next_finding)
        else:
            neg_findings.append(next_finding)

        # Suggest next finding
        next_finding = kb.suggest_next_finding(current_findings, neg_findings)


        if not next_finding:
            # print("No more findings to ask about.")
            break

    return conversation

def generate_question(finding):
    try: 
        return random.choice(questions[finding])
    except: 
        print("no questions for " + finding)

# %%
out = []

for case in cases:
    out.append({
        "encounter_id" : case["encounter_id"],
        "findings" : case["findings"],
        "turns" : simulate_conversation(kb, case["findings"])
    })

out
# Out:
# [{'encounter_id': 0,
#   'findings': ['fever',
#    'vaginal dryness',
#    'nipple discharge',
#    'night sweats',
#    'unexplained weight loss',
#    'leg cramps',
#    'throat pain',
#    'shoulder pain',
#    'elbow pain',
#    'vomiting'],
#   'turns': [{'doctor_q': 'When did your headache start?',
#     'patient_a': 'No',
#     'finding_queried': 'headache',
#     'response_positive': False},
#    {'doctor_q': 'Do you have a fever?',
#     'patient_a': 'Yes',
#     'finding_queried': 'fever',
#     'response_positive': True},
#    {'doctor_q': 'When did your shortness of breath start?',
#     'patient_a': 'No',
#     'finding_queried': 'shortness of breath',
#     'response_positive': False},
#    {'doctor_q': 'Have you felt nauseous a lot recently?',
#     'patient_a': 'No',
#     'finding_queried': 'nausea',
#     'response_positive': False},
#    {'doctor_q': 'Are you experiencing cough?',
#     'patient_a': 'No',
#     'finding_queried': 'cough',
#     'response_positive': False},
#    {'doctor_q': 'Have you been experiencing insomnia?',
#     'patient_a': 'No',
#     'finding_queried': 'insomnia',
#     'response_positive': False},
#    {'doctor_q': 'Has your back pain gotten better or worse recently?',
#     'patient_a': 'No',
#     'finding_queried': 'back pain',
#     'response_positive': False},
#    {'doctor_q': 'Do you have any abdominal pain?',
#     'patient_a': 'No',
#     'finding_queried': 'abdominal pain',
#     'response_positive': False},
#    {'doctor_q': 'Do you have chills?',
#     'patient_a': 'No',
#     'finding_queried': 'chills',
#     'response_positive': False},
#    {'doctor_q': 'Are you experiencing diarrhea?',
#     'patient_a': 'No',
#     'finding_queried': 'diarrhea',
#     'response_positive': False}]},
#  {'encounter_id': 1,
#   'findings': ['night sweats',
#    'chills',
#    'cough',
#    'breast lumps',
#    'diarrhea',
#    'muscle pain',
#    'abdominal pain',
#    'nasal congestion',
#    'runny nose',
#    'leg cramps'],
#   'turns': [{'doctor_q': 'When did your numbness start?',
#     'patient_a': 'No',
#     'finding_queried': 'numbness',
#     'response_positive': False},
#    {'doctor_q': 'Do you have a fever?',
#     'patient_a': 'No',
#     'finding_queried': 'fever',
#     'response_positive': False},
#    {'doctor_q': 'Are you experiencing shortness of breath?',
#     'patient_a': 'No',
#     'finding_queried': 'shortness of breath',
#     'response_positive': False},
#    {'doctor_q': 'Do you have any abdominal pain?',
#     'patient_a': 'Yes',
#     'finding_queried': 'abdominal pain',
#     'response_positive': True},
#    {'doctor_q': 'Are you feeling nauseous?',
#     'patient_a': 'No',
#     'finding_queried': 'nausea',
#     'response_positive': False},
#    {'doctor_q': 'Do you have trouble falling asleep at night?',
#     'patient_a': 'No',
#     'finding_queried': 'insomnia',
#     'response_positive': False},
#    {'doctor_q': 'Have you been experiencing any cough recently?',
#     'patient_a': 'Yes',
#     'finding_queried': 'cough',
#     'response_positive': True},
#    {'doctor_q': 'Are you experiencing diarrhea?',
#     'patient_a': 'Yes',
#     'finding_queried': 'diarrhea',
#     'response_positive': True},
#    {'doctor_q': 'Do you have chills?',
#     'patient_a': 'Yes',
#     'finding_queried': 'chills',
#     'response_positive': True},
#    {'doctor_q': 'When did your back pain start?',
#     'patient_a': 'No',
#     'finding_queried': 'back pain',
#     'response_positive': False}]},
#  {'encounter_id': 2,
#   'findings': ['nosebleeds',
#    'throat pain',
#    'breast rash',
#    'eye pain',
#    'muscle pain',
#    'nasal congestion',
#    'vaginal bleeding',
#    'neck pain',
#    'vaginal dryness',
#    'nipple discharge'],
#   'turns': [{'doctor_q': 'Have you vomited recently?',
#     'patient_a': 'No',
#     'finding_queried': 'vomiting',
#     'response_positive': False},
#    {'doctor_q': 'Have you had a fever recently?',
#     'patient_a': 'No',
#     'finding_queried': 'fever',
#     'response_positive': False},
#    {'doctor_q': 'Have you been experiencing any shortness of breath recently?',
#     'patient_a': 'No',
#     'finding_queried': 'shortness of breath',
#     'response_positive': False},
#    {'doctor_q': 'Have you been experiencing any abdominal pain recently?',
#     'patient_a': 'No',
#     'finding_queried': 'abdominal pain',
#     'response_positive': False},
#    {'doctor_q': 'Have you been experiencing insomnia?',
#     'patient_a': 'No',
#     'finding_queried': 'insomnia',
#     'response_positive': False},
#    {'doctor_q': 'Has your cough gotten better or worse recently?',
#     'patient_a': 'No',
#     'finding_queried': 'cough',
#     'response_positive': False},
#    {'doctor_q': 'Do you have chills?',
#     'patient_a': 'No',
#     'finding_queried': 'chills',
#     'response_positive': False},
#    {'doctor_q': 'Are you experiencing headache?',
#     'patient_a': 'No',
#     'finding_queried': 'headache',
#     'response_positive': False},
#    {'doctor_q': 'Do you have any diarrhea?',
#     'patient_a': 'No',
#     'finding_queried': 'diarrhea',
#     'response_positive': False},
#    {'doctor_q': 'Do you have any numbness?',
#     'patient_a': 'No',
#     'finding_queried': 'numbness',
#     'response_positive': False}]},
#  {'encounter_id': 3,
#   'findings': ['groin pain',
#    'leg pain',
#    'dry orgasm',
#    'leg cramps',
#    'joint pain',
#    'vomiting',
#    'rectal bleeding',
#    'pelvic pain',
#    'frequent bowel movements',
#    'vaginal discharge'],
#   'turns': [{'doctor_q': 'Have you had a fever recently?',
#     'patient_a': 'No',
#     'finding_queried': 'fever',
#     'response_positive': False},
#    {'doctor_q': 'When did your shortness of breath start?',
#     'patient_a': 'No',
#     'finding_queried': 'shortness of breath',
#     'response_positive': False},
#    {'doctor_q': 'When did your abdominal pain start?',
#     'patient_a': 'No',
#     'finding_queried': 'abdominal pain',
#     'response_positive': False},
#    {'doctor_q': 'Have you been experiencing insomnia?',
#     'patient_a': 'No',
#     'finding_queried': 'insomnia',
#     'response_positive': False},
#    {'doctor_q': 'When did your cough start?',
#     'patient_a': 'No',
#     'finding_queried': 'cough',
#     'response_positive': False},
#    {'doctor_q': 'Have you felt nauseous a lot recently?',
#     'patient_a': 'No',
#     'finding_queried': 'nausea',
#     'response_positive': False},
#    {'doctor_q': 'Do you have chills?',
#     'patient_a': 'No',
#     'finding_queried': 'chills',
#     'response_positive': False},
#    {'doctor_q': 'Have you been experiencing any headache recently?',
#     'patient_a': 'No',
#     'finding_queried': 'headache',
#     'response_positive': False},
#    {'doctor_q': 'Do you have any diarrhea?',
#     'patient_a': 'No',
#     'finding_queried': 'diarrhea',
#     'response_positive': False},
#    {'doctor_q': 'Are you experiencing numbness?',
#     'patient_a': 'No',
#     'finding_queried': 'numbness',
#     'response_positive': False}]},
#  {'encounter_id': 4,
#   'findings': ['back pain',
#    'joint pain',
#    'frequent bowel movements',
#    'muscle pain',
#    'watery eyes',
#    'breast lumps',
#    'shortness of breath',
#    'chills',
#    'foot pain',
#    'nipple discharge'],
#   'turns': [{'doctor_q': 'Do you have chills?',
#     'patient_a': 'Yes',
#     'finding_queried': 'chills',
#     'response_positive': True},
#    {'doctor_q': 'Have you had a fever recently?',
#     'patient_a': 'No',
#     'finding_queried': 'fever',
#     'response_positive': False},
#    {'doctor_q': 'Have you been experiencing any shortness of breath recently?',
#     'patient_a': 'Yes',
#     'finding_queried': 'shortness of breath',
#     'response_positive': True},
#    {'doctor_q': 'Do you have any cough?',
#     'patient_a': 'No',
#     'finding_queried': 'cough',
#     'response_positive': False},
#    {'doctor_q': 'Have you felt nauseous a lot recently?',
#     'patient_a': 'No',
#     'finding_queried': 'nausea',
#     'response_positive': False},
#    {'doctor_q': 'Have you been experiencing insomnia?',
#     'patient_a': 'No',
#     'finding_queried': 'insomnia',
#     'response_positive': False},
#    {'doctor_q': 'Do you have any abdominal pain?',
#     'patient_a': 'No',
#     'finding_queried': 'abdominal pain',
#     'response_positive': False},
#    {'doctor_q': 'Do you have any dizziness?',
#     'patient_a': 'No',
#     'finding_queried': 'dizziness',
#     'response_positive': False},
#    {'doctor_q': 'Have you been experiencing any diarrhea recently?',
#     'patient_a': 'No',
#     'finding_queried': 'diarrhea',
#     'response_positive': False},
#    {'doctor_q': 'When did your headache start?',
#     'patient_a': 'No',
#     'finding_queried': 'headache',
#     'response_positive': False}]},
#  {'encounter_id': 5,
#   'findings': ['nasal congestion',
#    'frequent bowel movements',
#    'memory loss',
#    'nausea',
#    'shortness of breath',
#    'fatigue',
#    'back pain',
#    'heel pain',
#    'nipple discharge',
#    'dizziness'],
#   'turns': [{'doctor_q': 'Do you have any abdominal pain?',
#     'patient_a': 'No',
#     'finding_queried': 'abdominal pain',
#     'response_positive': False},
#    {'doctor_q': 'Have you had a fever recently?',
#     'patient_a': 'No',
#     'finding_queried': 'fever',
#     'response_positive': False},
#    {'doctor_q': 'Are you experiencing shortness of breath?',
#     'patient_a': 'Yes',
#     'finding_queried': 'shortness of breath',
#     'response_positive': True},
#    {'doctor_q': 'When did your cough start?',
#     'patient_a': 'No',
#     'finding_queried': 'cough',
#     'response_positive': False},
#    {'doctor_q': 'Do you have trouble falling asleep at night?',
#     'patient_a': 'No',
#     'finding_queried': 'insomnia',
#     'response_positive': False},
#    {'doctor_q': 'Have you felt nauseous a lot recently?',
#     'patient_a': 'Yes',
#     'finding_queried': 'nausea',
#     'response_positive': True},
#    {'doctor_q': 'Do you have chills?',
#     'patient_a': 'No',
#     'finding_queried': 'chills',
#     'response_positive': False},
#    {'doctor_q': 'When did your headache start?',
#     'patient_a': 'No',
#     'finding_queried': 'headache',
#     'response_positive': False},
#    {'doctor_q': 'Has your diarrhea gotten better or worse recently?',
#     'patient_a': 'No',
#     'finding_queried': 'diarrhea',
#     'response_positive': False},
#    {'doctor_q': 'When did your dizziness start?',
#     'patient_a': 'Yes',
#     'finding_queried': 'dizziness',
#     'response_positive': True}]},
#  {'encounter_id': 6,
#   'findings': ['frequent urination',
#    'shoulder pain',
#    'muscle pain',
#    'headache',
#    'frequent bowel movements',
#    'arm pain',
#    'numbness',
#    'unexplained weight loss',
#    'nipple discharge',
#    'leg swelling'],
#   'turns': [{'doctor_q': 'Has your back pain gotten better or worse recently?',
#     'patient_a': 'No',
#     'finding_queried': 'back pain',
#     'response_positive': False},
#    {'doctor_q': 'Do you have a fever?',
#     'patient_a': 'No',
#     'finding_queried': 'fever',
#     'response_positive': False},
#    {'doctor_q': 'Has your shortness of breath gotten better or worse recently?',
#     'patient_a': 'No',
#     'finding_queried': 'shortness of breath',
#     'response_positive': False},
#    {'doctor_q': 'Have you been experiencing any abdominal pain recently?',
#     'patient_a': 'No',
#     'finding_queried': 'abdominal pain',
#     'response_positive': False},
#    {'doctor_q': 'Do you have trouble falling asleep at night?',
#     'patient_a': 'No',
#     'finding_queried': 'insomnia',
#     'response_positive': False},
#    {'doctor_q': 'When did your diarrhea start?',
#     'patient_a': 'No',
#     'finding_queried': 'diarrhea',
#     'response_positive': False},
#    {'doctor_q': 'Have you felt nauseous a lot recently?',
#     'patient_a': 'No',
#     'finding_queried': 'nausea',
#     'response_positive': False},
#    {'doctor_q': 'Do you have chills?',
#     'patient_a': 'No',
#     'finding_queried': 'chills',
#     'response_positive': False},
#    {'doctor_q': 'Do you have any dizziness?',
#     'patient_a': 'No',
#     'finding_queried': 'dizziness',
#     'response_positive': False},
#    {'doctor_q': 'Are you experiencing headache?',
#     'patient_a': 'Yes',
#     'finding_queried': 'headache',
#     'response_positive': True}]},
#  {'encounter_id': 7,
#   'findings': ['runny nose',
#    'ankle pain',
#    'shoulder pain',
#    'fever',
#    'vaginal dryness',
#    'fatigue',
#    'coughing up blood',
#    'abdominal pain',
#    'chills',
#    'rectal bleeding'],
#   'turns': [{'doctor_q': 'Have you had a fever recently?',
#     'patient_a': 'Yes',
#     'finding_queried': 'fever',
#     'response_positive': True},
#    {'doctor_q': 'Do you have any cough?',
#     'patient_a': 'No',
#     'finding_queried': 'cough',
#     'response_positive': False},
#    {'doctor_q': 'Have you felt nauseous a lot recently?',
#     'patient_a': 'No',
#     'finding_queried': 'nausea',
#     'response_positive': False},
#    {'doctor_q': 'Are you experiencing shortness of breath?',
#     'patient_a': 'No',
#     'finding_queried': 'shortness of breath',
#     'response_positive': False},
#    {'doctor_q': 'Do you have trouble falling asleep at night?',
#     'patient_a': 'No',
#     'finding_queried': 'insomnia',
#     'response_positive': False},
#    {'doctor_q': 'Are you experiencing abdominal pain?',
#     'patient_a': 'Yes',
#     'finding_queried': 'abdominal pain',
#     'response_positive': True},
#    {'doctor_q': 'Has your back pain gotten better or worse recently?',
#     'patient_a': 'No',
#     'finding_queried': 'back pain',
#     'response_positive': False},
#    {'doctor_q': 'Do you have any headache?',
#     'patient_a': 'No',
#     'finding_queried': 'headache',
#     'response_positive': False},
#    {'doctor_q': 'Are you experiencing diarrhea?',
#     'patient_a': 'No',
#     'finding_queried': 'diarrhea',
#     'response_positive': False},
#    {'doctor_q': 'Do you have chills?',
#     'patient_a': 'Yes',
#     'finding_queried': 'chills',
#     'response_positive': True}]},
#  {'encounter_id': 8,
#   'findings': ['back pain',
#    'hip pain',
#    'blood clots',
#    'chills',
#    'pelvic pain',
#    'dry orgasm',
#    'foot pain',
#    'nipple discharge',
#    'leg swelling',
#    'leg pain'],
#   'turns': [{'doctor_q': 'When did your hip pain start?',
#     'patient_a': 'Yes',
#     'finding_queried': 'hip pain',
#     'response_positive': True},
#    {'doctor_q': 'Do you have a fever?',
#     'patient_a': 'No',
#     'finding_queried': 'fever',
#     'response_positive': False},
#    {'doctor_q': 'Have you been experiencing any shortness of breath recently?',
#     'patient_a': 'No',
#     'finding_queried': 'shortness of breath',
#     'response_positive': False},
#    {'doctor_q': 'Have you been experiencing any abdominal pain recently?',
#     'patient_a': 'No',
#     'finding_queried': 'abdominal pain',
#     'response_positive': False},
#    {'doctor_q': 'Do you have trouble falling asleep at night?',
#     'patient_a': 'No',
#     'finding_queried': 'insomnia',
#     'response_positive': False},
#    {'doctor_q': 'Are you experiencing cough?',
#     'patient_a': 'No',
#     'finding_queried': 'cough',
#     'response_positive': False},
#    {'doctor_q': 'Have you felt nauseous a lot recently?',
#     'patient_a': 'No',
#     'finding_queried': 'nausea',
#     'response_positive': False},
#    {'doctor_q': 'Do you have chills?',
#     'patient_a': 'Yes',
#     'finding_queried': 'chills',
#     'response_positive': True},
#    {'doctor_q': 'Has your diarrhea gotten better or worse recently?',
#     'patient_a': 'No',
#     'finding_queried': 'diarrhea',
#     'response_positive': False},
#    {'doctor_q': 'Have you been experiencing any headache recently?',
#     'patient_a': 'No',
#     'finding_queried': 'headache',
#     'response_positive': False}]},
#  {'encounter_id': 9,
#   'findings': ['back pain',
#    'neck pain',
#    'breast rash',
#    'ankle pain',
#    'vomiting',
#    'leg pain',
#    'insomnia',
#    'frequent urination',
#    'eye pain',
#    'arm pain'],
#   'turns': [{'doctor_q': 'When did your pelvic pain start?',
#     'patient_a': 'No',
#     'finding_queried': 'pelvic pain',
#     'response_positive': False},
#    {'doctor_q': 'Have you had a fever recently?',
#     'patient_a': 'No',
#     'finding_queried': 'fever',
#     'response_positive': False},
#    {'doctor_q': 'Do you have any shortness of breath?',
#     'patient_a': 'No',
#     'finding_queried': 'shortness of breath',
#     'response_positive': False},
#    {'doctor_q': 'Have you been experiencing any abdominal pain recently?',
#     'patient_a': 'No',
#     'finding_queried': 'abdominal pain',
#     'response_positive': False},
#    {'doctor_q': 'Do you have trouble falling asleep at night?',
#     'patient_a': 'Yes',
#     'finding_queried': 'insomnia',
#     'response_positive': True},
#    {'doctor_q': 'When did your cough start?',
#     'patient_a': 'No',
#     'finding_queried': 'cough',
#     'response_positive': False},
#    {'doctor_q': 'Are you feeling nauseous?',
#     'patient_a': 'No',
#     'finding_queried': 'nausea',
#     'response_positive': False},
#    {'doctor_q': 'Do you have any back pain?',
#     'patient_a': 'Yes',
#     'finding_queried': 'back pain',
#     'response_positive': True},
#    {'doctor_q': 'Are you experiencing diarrhea?',
#     'patient_a': 'No',
#     'finding_queried': 'diarrhea',
#     'response_positive': False},
#    {'doctor_q': 'When did your headache start?',
#     'patient_a': 'No',
#     'finding_queried': 'headache',
#     'response_positive': False}]}]

# %%
def chatbot_loop():
    print("Chatbot: Hello, I'm going to ask you some questions about your symptoms.")
    current_findings = []
    neg_findings = []
    next_finding = kb.get_random_finding()
    while len(current_findings) + len(neg_findings) < 10:

        question = generate_question(next_finding)

        print(f"Chatbot: {question}")
        user_input = input("You: ")
        if any(word in user_input.lower() for word in ["yes", "yeah", "y", "i have", "sure"]):
            current_findings.append(next_finding)
        else:
            neg_findings.append(next_finding)
        
        # Suggest next finding
        next_finding = kb.suggest_next_finding(current_findings, neg_findings)

    print("Chatbot: Thank you for your time.")
    

def generate_question(finding):
    try: 
        return random.choice(questions[finding])
    except: 
        print("no questions for " + finding)
